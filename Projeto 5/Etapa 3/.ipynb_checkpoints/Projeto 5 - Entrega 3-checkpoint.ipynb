# %% [markdown]
# # Projeto 5 - Regressão linera múltipla
#
# ## Ciência dos dados
#
# ## Felipe Viacava e Felipe Giorgi

# %% [markdown]
# ### Entrega 3: Análise de regressão

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import random
from scipy import stats
import statsmodels.formula.api as sm

print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Felipe Giorgi\Desktop\3° Semestre\DP - Ciência dos Dados\CDV\CD1S17\Projeto 5

# %%
idh = pd.read_excel('Indicator_HDI.xlsx', index_col=0)
fs = pd.read_excel('indicator food_consumption.xlsx', index_col=0)
crc = pd.read_excel('indicator colon and rectum male incidence.xlsx', index_col=0)

idh.shape
# Out:
# (270, 9)

# %%
IDH = idh[2000]
FS = fs[2002]
CRC = crc[2002]

# %%
data = pd.concat([IDH, FS, CRC], axis = 1, join='inner')

# %%
data
# Out:
#                          2000     2002  2002
# Afghanistan             0.230      NaN   5.2
# Albania                 0.691  2864.93  28.1
# Algeria                 0.624  3034.33   5.5
# Angola                  0.384  1833.90   4.3
# Argentina               0.749  2965.90  30.1
# Armenia                 0.643  2150.57   8.5
# Australia               0.906  3073.21  47.4
# Austria                 0.839  3743.90  42.1
# Azerbaijan                NaN  2647.96   5.7
# Bahamas                 0.752  2684.17  15.2
# Bahrain                 0.773      NaN  12.3
# Bangladesh              0.422  2179.58   1.0
# Barbados                  NaN  3056.06  24.1
# Belarus                   NaN  2968.65  25.8
# Belgium                 0.876  3728.34  37.0
# Belize                  0.668  2651.12   4.9
# Benin                   0.378  2427.33   5.1
# Bhutan                    NaN      NaN   4.7
# Bolivia                 0.612  2173.19  15.9
# Bosnia and Herzegovina    NaN  2863.94  33.9
# Botswana                0.585  2181.02   6.2
# Brazil                  0.665  2930.63  14.4
# Brunei                  0.818  2977.59  15.7
# Bulgaria                0.715  2771.69  25.6
# Burkina Faso              NaN  2587.79   4.0
# Burundi                 0.245  1700.41   6.7
# Cambodia                0.438  2083.05  11.3
# Cameroon                0.427  2194.48   4.3
# Canada                  0.879  3531.56  42.2
# Cape Verde              0.523  2333.23   5.1
# ...                       ...      ...   ...
# Somalia                   NaN      NaN   6.7
# South Africa            0.616  2902.73  12.3
# Spain                   0.839  3372.53  36.8
# Sri Lanka               0.633  2363.61   5.0
# Sudan                   0.357  2171.35   5.3
# Suriname                  NaN  2437.69  10.1
# Swaziland               0.492  2277.82   4.0
# Sweden                  0.894  3112.77  33.4
# Switzerland             0.873  3404.86  42.7
# Syria                   0.583  3036.04  18.0
# Tajikistan              0.527  1945.24   2.5
# Tanzania                0.364  1977.76   4.2
# Thailand                0.626  2468.47  10.7
# Togo                    0.408  2060.73   5.1
# Trinidad and Tobago     0.701  2690.67  14.8
# Tunisia                 0.630  3228.05   6.3
# Turkey                  0.634  3430.27   9.1
# Turkmenistan              NaN  2671.81   2.2
# Uganda                  0.372  2315.66   7.7
# Ukraine                 0.669  3048.39  27.5
# United Arab Emirates    0.753  3131.05  12.2
# United Kingdom          0.833  3434.04  39.2
# United States           0.897  3753.78  44.6
# Uruguay                 0.736  2782.66  39.6
# Uzbekistan                NaN  2298.29   3.7
# Vanuatu                   NaN  2640.40   3.6
# Venezuela               0.656  2253.62  11.2
# Vietnam                 0.528  2541.65  11.8
# Zambia                  0.371  1884.89   6.6
# Zimbabwe                0.372  2072.55   7.2
#
# [166 rows x 3 columns]

# %%
data.dropna()
data.columns = ["IDH", "FS", "CRC"]
data.head()
# Out:
#                IDH       FS   CRC
# Afghanistan  0.230      NaN   5.2
# Albania      0.691  2864.93  28.1
# Algeria      0.624  3034.33   5.5
# Angola       0.384  1833.90   4.3
# Argentina    0.749  2965.90  30.1

# %%
fig = plt.figure(figsize=(10, 10))
plt.subplot(311)
plt.scatter(data.IDH, data.FS, c='red', alpha=0.8)
plt.title('IDH versus Consumo')
plt.xlabel('Indice de desenvolvimento humano')
plt.ylabel('Consumo de calorias por pessoa')

plt.subplot(312)
plt.scatter(data.IDH, data.CRC, c='red', alpha=0.8)
plt.title('IDH versus CRC')
plt.xlabel('Indice de desenvolvimento humano')
plt.ylabel('Novos casos de cancer de colo retal por 100.000 homens')

plt.subplot(313)
plt.scatter(data.FS, data.CRC, c='red', alpha=0.8)
plt.title('FS versus CRC')
plt.xlabel('Novos casos de cancer de colo retal por 100.000 homens')
plt.ylabel('Consumo de calorias por pessoa')

plt.tight_layout()
plt.show()

# %%
data.corr(method='pearson')
# Out:
#           IDH        FS       CRC
# IDH  1.000000  0.845743  0.779997
# FS   0.845743  1.000000  0.699225
# CRC  0.779997  0.699225  1.000000
